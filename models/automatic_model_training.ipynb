# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook demonstrates how to train custom openWakeWord models using pre-defined datasets and an automated process for dataset generation and training. While not guaranteed to always produce the best performing model, the methods shown in this notebook often produce baseline models with releatively strong performance.
#
# Manual data preparation and model training (e.g., see the [training models](training_models.ipynb) notebook) remains an option for when full control over the model development process is needed.
#
# At a high level, the automatic training process takes advantages of several techniques to try and produce a good model, including:
#
# - Early-stopping and checkpoint averaging (similar to [stochastic weight averaging](https://arxiv.org/abs/1803.05407)) to search for the best models found during training, according to the validation data
# - Variable learning rates with cosine decay and multiple cycles
# - Adaptive batch construction to focus on only high-loss examples when the model begins to converge, combined with gradient accumulation to ensure that batch sizes are still large enough for stable training
# - Cycical weight schedules for negative examples to help the model reduce false-positive rates
#
# See the contents of the `train.py` file for more details.

# %% [markdown]
# # Environment Setup

# %% [markdown]
# To begin, we'll need to install the requirements for training custom models. In particular, a relatively recent version of Pytorch and custom fork of the [piper-sample-generator](https://github.com/dscripka/piper-sample-generator) library for generating synthetic examples for the custom model.
#
# **Important Note!** Currently, automated model training is only supported on linux systems due to the requirements of the text to speech library used for synthetic sample generation (Piper). It may be possible to use Piper on Windows/Mac systems, but that has not (yet) been tested.

# %%
## Environment setup

# install piper-sample-generator (currently only supports linux systems)
# !git clone https://github.com/rhasspy/piper-sample-generator
# !wget -O piper-sample-generator/models/en_US-libritts_r-medium.pt 'https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/en_US-libritts_r-medium.pt'
# !pip install piper-phonemize

# install openwakeword (full installation to support training)
# !git clone https://github.com/dscripka/openwakeword
# !pip install -e ./openwakeword
# !cd openwakeword

# install other dependencies
# !pip install mutagen==1.47.0
# !pip install torchinfo==1.8.0
# !pip install torchmetrics==1.2.0
# !pip install speechbrain==0.5.14
# !pip install audiomentations==0.33.0
# !pip install torch-audiomentations==0.11.0
# !pip install acoustics==0.2.6
# !pip install tensorflow-cpu==2.8.1
# !pip install tensorflow_probability==0.16.0
# !pip install onnx_tf==1.10.0
# !pip install pronouncing==0.2.0
# !pip install datasets==2.14.6
# !pip install deep-phonemizer==0.0.19

# Download required models (workaround for Colab)
import os
os.makedirs("./openwakeword/openwakeword/resources/models")
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.onnx -O ./openwakeword/openwakeword/resources/models/embedding_model.onnx
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.tflite -O ./openwakeword/openwakeword/resources/models/embedding_model.tflite
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/melspectrogram.onnx -O ./openwakeword/openwakeword/resources/models/melspectrogram.onnx
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/melspectrogram.tflite -O ./openwakeword/openwakeword/resources/models/melspectrogram.tflite
# Out:
# fatal: destination path 'piper-sample-generator' already exists and is not an empty directory.
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# ERROR: Could not find a version that satisfies the requirement piper-phonemize (from versions: none)
# ERROR: No matching distribution found for piper-phonemize
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting webrtcvad
#   Using cached webrtcvad-2.0.10.tar.gz (66 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: webrtcvad
#   Building wheel for webrtcvad (setup.py): started
#   Building wheel for webrtcvad (setup.py): finished with status 'error'
#   Running setup.py clean for webrtcvad
# Failed to build webrtcvad
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [23 lines of output]
#       C:\Git\pnd\dann-of-thursday\.venv\Lib\site-packages\setuptools\_distutils\dist.py:287: UserWarning: Unknown distribution option: 'test_suite'
#         warnings.warn(msg)
#       C:\Git\pnd\dann-of-thursday\.venv\Lib\site-packages\setuptools\dist.py:765: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: MIT License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-311
#       copying webrtcvad.py -> build\lib.win-amd64-cpython-311
#       running build_ext
#       building '_webrtcvad' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for webrtcvad
# ERROR: Could not build wheels for webrtcvad, which is required to install pyproject.toml-based projects
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# fatal: destination path 'openwakeword' already exists and is not an empty directory.
# Obtaining file:///C:/Git/pnd/dann-of-thursday/models/openwakeword
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: onnxruntime<2,>=1.10.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from openwakeword==0.6.0) (1.24.1)
# Requirement already satisfied: tqdm<5.0,>=4.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from openwakeword==0.6.0) (4.67.3)
# Requirement already satisfied: scipy<2,>=1.3 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from openwakeword==0.6.0) (1.17.0)
# Requirement already satisfied: scikit-learn<2,>=1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from openwakeword==0.6.0) (1.8.0)
# Requirement already satisfied: requests<3,>=2.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from openwakeword==0.6.0) (2.32.5)
# Requirement already satisfied: flatbuffers in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (25.12.19)
# Requirement already satisfied: numpy>=1.21.6 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (2.3.5)
# Requirement already satisfied: packaging in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (26.0)
# Requirement already satisfied: protobuf in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (6.33.5)
# Requirement already satisfied: sympy in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (1.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests<3,>=2.0->openwakeword==0.6.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests<3,>=2.0->openwakeword==0.6.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests<3,>=2.0->openwakeword==0.6.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests<3,>=2.0->openwakeword==0.6.0) (2026.1.4)
# Requirement already satisfied: joblib>=1.3.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from scikit-learn<2,>=1->openwakeword==0.6.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from scikit-learn<2,>=1->openwakeword==0.6.0) (3.6.0)
# Requirement already satisfied: colorama in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tqdm<5.0,>=4.0->openwakeword==0.6.0) (0.4.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from sympy->onnxruntime<2,>=1.10.0->openwakeword==0.6.0) (1.3.0)
# Building wheels for collected packages: openwakeword
#   Building editable for openwakeword (pyproject.toml): started
#   Building editable for openwakeword (pyproject.toml): finished with status 'done'
#   Created wheel for openwakeword: filename=openwakeword-0.6.0-0.editable-py3-none-any.whl size=17563 sha256=29e7138f4eca8fe4025fa608f4efc7fa5b97edd0947a570c471e5e7a917e0137
#   Stored in directory: C:\Users\r3dpn\AppData\Local\Temp\pip-ephem-wheel-cache-qxdn6gly\wheels\f3\81\a6\1f0ad71c2b05fa9f79dde0120d12fd312cab2a66d271207f0a
# Successfully built openwakeword
# Installing collected packages: openwakeword
#   Attempting uninstall: openwakeword
#     Found existing installation: openwakeword 0.6.0
#     Uninstalling openwakeword-0.6.0:
#       Successfully uninstalled openwakeword-0.6.0
# Successfully installed openwakeword-0.6.0
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: mutagen==1.47.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (1.47.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: torchinfo==1.8.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (1.8.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: torchmetrics==1.2.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (1.2.0)
# Requirement already satisfied: numpy>1.20.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torchmetrics==1.2.0) (2.3.5)
# Requirement already satisfied: torch>=1.8.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torchmetrics==1.2.0) (2.10.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torchmetrics==1.2.0) (0.15.2)
# Requirement already satisfied: packaging>=17.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics==1.2.0) (26.0)
# Requirement already satisfied: setuptools in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics==1.2.0) (82.0.0)
# Requirement already satisfied: typing_extensions in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics==1.2.0) (4.15.0)
# Requirement already satisfied: filelock in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.8.1->torchmetrics==1.2.0) (3.20.3)
# Requirement already satisfied: sympy>=1.13.3 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.8.1->torchmetrics==1.2.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.8.1->torchmetrics==1.2.0) (3.6.1)
# Requirement already satisfied: jinja2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.8.1->torchmetrics==1.2.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.8.1->torchmetrics==1.2.0) (2023.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.8.1->torchmetrics==1.2.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from jinja2->torch>=1.8.1->torchmetrics==1.2.0) (3.0.3)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: speechbrain==0.5.14 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (0.5.14)
# Requirement already satisfied: hyperpyyaml in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from speechbrain==0.5.14) (1.2.3)
# Requirement already satisfied: joblib in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from speechbrain==0.5.14) (1.5.3)
# Requirement already satisfied: numpy in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from speechbrain==0.5.14) (2.3.5)
# Requirement already satisfied: packaging in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from speechbrain==0.5.14) (26.0)
# Requirement already satisfied: scipy in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from speechbrain==0.5.14) (1.17.0)
# Requirement already satisfied: sentencepiece in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from speechbrain==0.5.14) (0.2.1)
# Requirement already satisfied: torch>=1.9 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from speechbrain==0.5.14) (2.10.0)
# Requirement already satisfied: torchaudio in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from speechbrain==0.5.14) (2.10.0)
# Requirement already satisfied: tqdm in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from speechbrain==0.5.14) (4.67.3)
# Requirement already satisfied: huggingface-hub in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from speechbrain==0.5.14) (0.36.2)
# Requirement already satisfied: filelock in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.9->speechbrain==0.5.14) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.9->speechbrain==0.5.14) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.9->speechbrain==0.5.14) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.9->speechbrain==0.5.14) (3.6.1)
# Requirement already satisfied: jinja2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.9->speechbrain==0.5.14) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.9->speechbrain==0.5.14) (2023.10.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from huggingface-hub->speechbrain==0.5.14) (6.0.3)
# Requirement already satisfied: requests in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from huggingface-hub->speechbrain==0.5.14) (2.32.5)
# Requirement already satisfied: colorama in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tqdm->speechbrain==0.5.14) (0.4.6)
# Requirement already satisfied: ruamel.yaml<0.19.0,>=0.17.28 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from hyperpyyaml->speechbrain==0.5.14) (0.18.17)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.15 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from ruamel.yaml<0.19.0,>=0.17.28->hyperpyyaml->speechbrain==0.5.14) (0.2.15)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.9->speechbrain==0.5.14) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from jinja2->torch>=1.9->speechbrain==0.5.14) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests->huggingface-hub->speechbrain==0.5.14) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests->huggingface-hub->speechbrain==0.5.14) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests->huggingface-hub->speechbrain==0.5.14) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests->huggingface-hub->speechbrain==0.5.14) (2026.1.4)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: audiomentations==0.33.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (0.33.0)
# Requirement already satisfied: numpy>=1.18.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from audiomentations==0.33.0) (2.3.5)
# Requirement already satisfied: librosa!=0.10.0,<0.11.0,>=0.8.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from audiomentations==0.33.0) (0.10.2.post1)
# Requirement already satisfied: scipy<2,>=1.4.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from audiomentations==0.33.0) (1.17.0)
# Requirement already satisfied: soxr<1.0.0,>=0.3.2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from audiomentations==0.33.0) (0.5.0.post1)
# Requirement already satisfied: audioread>=2.1.9 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.1.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.8.0)
# Requirement already satisfied: joblib>=0.14 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (5.2.1)
# Requirement already satisfied: numba>=0.51.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.63.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.9.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (4.15.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.1.2)
# Requirement already satisfied: packaging in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from lazy-loader>=0.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (26.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from numba>=0.51.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.46.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (4.5.1)
# Requirement already satisfied: requests>=2.19.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2.32.5)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from scikit-learn>=0.20.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from soundfile>=0.12.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2.0.0)
# Requirement already satisfied: pycparser in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2026.1.4)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: torch-audiomentations==0.11.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (0.11.0)
# Requirement already satisfied: julius<0.3,>=0.2.3 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch-audiomentations==0.11.0) (0.2.7)
# Requirement already satisfied: librosa>=0.6.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch-audiomentations==0.11.0) (0.10.2.post1)
# Requirement already satisfied: torch>=1.7.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch-audiomentations==0.11.0) (2.10.0)
# Requirement already satisfied: torchaudio>=0.7.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch-audiomentations==0.11.0) (2.10.0)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch-audiomentations==0.11.0) (1.2.5)
# Requirement already satisfied: audioread>=2.1.9 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (3.1.0)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (2.3.5)
# Requirement already satisfied: scipy>=1.2.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.17.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.8.0)
# Requirement already satisfied: joblib>=0.14 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (5.2.1)
# Requirement already satisfied: numba>=0.51.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.63.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (4.15.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.1.2)
# Requirement already satisfied: filelock in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (3.20.3)
# Requirement already satisfied: sympy>=1.13.3 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (3.6.1)
# Requirement already satisfied: jinja2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (2023.10.0)
# Requirement already satisfied: primePy>=1.3 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations==0.11.0) (1.3)
# Requirement already satisfied: packaging>=21.3 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations==0.11.0) (26.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from numba>=0.51.0->librosa>=0.6.0->torch-audiomentations==0.11.0) (0.46.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (4.5.1)
# Requirement already satisfied: requests>=2.19.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2.32.5)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from scikit-learn>=0.20.0->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from soundfile>=0.12.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.7.0->torch-audiomentations==0.11.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from jinja2->torch>=1.7.0->torch-audiomentations==0.11.0) (3.0.3)
# Requirement already satisfied: pycparser in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2026.1.4)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: acoustics==0.2.6 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (0.2.6)
# Requirement already satisfied: numpy>=1.8 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from acoustics==0.2.6) (2.3.5)
# Requirement already satisfied: scipy>=0.16 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from acoustics==0.2.6) (1.17.0)
# Requirement already satisfied: matplotlib in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from acoustics==0.2.6) (3.10.8)
# Requirement already satisfied: six>=1.4.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from acoustics==0.2.6) (1.17.0)
# Requirement already satisfied: pandas>=0.15 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from acoustics==0.2.6) (3.0.0)
# Requirement already satisfied: tabulate in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from acoustics==0.2.6) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from pandas>=0.15->acoustics==0.2.6) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from pandas>=0.15->acoustics==0.2.6) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from matplotlib->acoustics==0.2.6) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from matplotlib->acoustics==0.2.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from matplotlib->acoustics==0.2.6) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from matplotlib->acoustics==0.2.6) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from matplotlib->acoustics==0.2.6) (26.0)
# Requirement already satisfied: pillow>=8 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from matplotlib->acoustics==0.2.6) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from matplotlib->acoustics==0.2.6) (3.3.2)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement tensorflow-cpu==2.8.1 (from versions: 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.1, 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0, 2.19.1, 2.20.0rc0, 2.20.0, 2.21.0rc0)
# ERROR: No matching distribution found for tensorflow-cpu==2.8.1
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tensorflow_probability==0.16.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (0.16.0)
# Requirement already satisfied: absl-py in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tensorflow_probability==0.16.0) (2.4.0)
# Requirement already satisfied: six>=1.10.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tensorflow_probability==0.16.0) (1.17.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tensorflow_probability==0.16.0) (2.3.5)
# Requirement already satisfied: decorator in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tensorflow_probability==0.16.0) (5.2.1)
# Requirement already satisfied: cloudpickle>=1.3 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tensorflow_probability==0.16.0) (3.1.2)
# Requirement already satisfied: gast>=0.3.2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tensorflow_probability==0.16.0) (0.7.0)
# Requirement already satisfied: dm-tree in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tensorflow_probability==0.16.0) (0.1.9)
# Requirement already satisfied: attrs>=18.2.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from dm-tree->tensorflow_probability==0.16.0) (25.4.0)
# Requirement already satisfied: wrapt>=1.11.2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from dm-tree->tensorflow_probability==0.16.0) (2.1.1)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: onnx_tf==1.10.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (1.10.0)
# Requirement already satisfied: onnx>=1.10.2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from onnx_tf==1.10.0) (1.20.1)
# Requirement already satisfied: PyYAML in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from onnx_tf==1.10.0) (6.0.3)
# Requirement already satisfied: tensorflow-addons in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from onnx_tf==1.10.0) (0.22.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from onnx>=1.10.2->onnx_tf==1.10.0) (2.3.5)
# Requirement already satisfied: protobuf>=4.25.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from onnx>=1.10.2->onnx_tf==1.10.0) (6.33.5)
# Requirement already satisfied: typing_extensions>=4.7.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from onnx>=1.10.2->onnx_tf==1.10.0) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from onnx>=1.10.2->onnx_tf==1.10.0) (0.5.4)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tensorflow-addons->onnx_tf==1.10.0) (2.13.3)
# Requirement already satisfied: packaging in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tensorflow-addons->onnx_tf==1.10.0) (26.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pronouncing==0.2.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (0.2.0)
# Requirement already satisfied: cmudict>=0.4.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from pronouncing==0.2.0) (1.1.3)
# Requirement already satisfied: importlib-metadata>=5 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from cmudict>=0.4.0->pronouncing==0.2.0) (8.7.1)
# Requirement already satisfied: importlib-resources>=5 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from cmudict>=0.4.0->pronouncing==0.2.0) (6.5.2)
# Requirement already satisfied: zipp>=3.20 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from importlib-metadata>=5->cmudict>=0.4.0->pronouncing==0.2.0) (3.23.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: datasets==2.14.6 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (2.14.6)
# Requirement already satisfied: numpy>=1.17 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from datasets==2.14.6) (2.3.5)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from datasets==2.14.6) (23.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from datasets==2.14.6) (0.3.7)
# Requirement already satisfied: pandas in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from datasets==2.14.6) (3.0.0)
# Requirement already satisfied: requests>=2.19.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from datasets==2.14.6) (2.32.5)
# Requirement already satisfied: tqdm>=4.62.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from datasets==2.14.6) (4.67.3)
# Requirement already satisfied: xxhash in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from datasets==2.14.6) (3.6.0)
# Requirement already satisfied: multiprocess in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from datasets==2.14.6) (0.70.15)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets==2.14.6) (2023.10.0)
# Requirement already satisfied: aiohttp in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from datasets==2.14.6) (3.13.3)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from datasets==2.14.6) (0.36.2)
# Requirement already satisfied: packaging in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from datasets==2.14.6) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from datasets==2.14.6) (6.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from aiohttp->datasets==2.14.6) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from aiohttp->datasets==2.14.6) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from aiohttp->datasets==2.14.6) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from aiohttp->datasets==2.14.6) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from aiohttp->datasets==2.14.6) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from aiohttp->datasets==2.14.6) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from aiohttp->datasets==2.14.6) (1.22.0)
# Requirement already satisfied: filelock in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.6) (3.20.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.6) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests>=2.19.0->datasets==2.14.6) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests>=2.19.0->datasets==2.14.6) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests>=2.19.0->datasets==2.14.6) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from requests>=2.19.0->datasets==2.14.6) (2026.1.4)
# Requirement already satisfied: colorama in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tqdm>=4.62.1->datasets==2.14.6) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from pandas->datasets==2.14.6) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from pandas->datasets==2.14.6) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets==2.14.6) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: deep-phonemizer==0.0.19 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (0.0.19)
# Requirement already satisfied: torch>=1.2.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from deep-phonemizer==0.0.19) (2.10.0)
# Requirement already satisfied: tqdm>=4.38.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from deep-phonemizer==0.0.19) (4.67.3)
# Requirement already satisfied: PyYAML>=5.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from deep-phonemizer==0.0.19) (6.0.3)
# Requirement already satisfied: tensorboard in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from deep-phonemizer==0.0.19) (2.20.0)
# Requirement already satisfied: certifi>=2022.12.7 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from deep-phonemizer==0.0.19) (2026.1.4)
# Requirement already satisfied: wheel>=0.38.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from deep-phonemizer==0.0.19) (0.46.3)
# Requirement already satisfied: setuptools>=65.5.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from deep-phonemizer==0.0.19) (82.0.0)
# Requirement already satisfied: filelock in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (3.6.1)
# Requirement already satisfied: jinja2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (2023.10.0)
# Requirement already satisfied: colorama in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tqdm>=4.38.0->deep-phonemizer==0.0.19) (0.4.6)
# Requirement already satisfied: packaging>=24.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from wheel>=0.38.0->deep-phonemizer==0.0.19) (26.0)
# Requirement already satisfied: absl-py>=0.4 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tensorboard->deep-phonemizer==0.0.19) (2.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tensorboard->deep-phonemizer==0.0.19) (1.78.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tensorboard->deep-phonemizer==0.0.19) (3.10.2)
# Requirement already satisfied: numpy>=1.12.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tensorboard->deep-phonemizer==0.0.19) (2.3.5)
# Requirement already satisfied: pillow in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tensorboard->deep-phonemizer==0.0.19) (12.1.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tensorboard->deep-phonemizer==0.0.19) (6.33.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tensorboard->deep-phonemizer==0.0.19) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from tensorboard->deep-phonemizer==0.0.19) (3.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.2.0->deep-phonemizer==0.0.19) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\git\pnd\dann-of-thursday\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard->deep-phonemizer==0.0.19) (3.0.3)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[1], line 31
#      29 # Download required models (workaround for Colab)
#      30 import os
# ---> 31 os.makedirs("./openwakeword/openwakeword/resources/models")
#      32 get_ipython().system('wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.onnx -O ./openwakeword/openwakeword/resources/models/embedding_model.onnx')
#      33 get_ipython().system('wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.tflite -O ./openwakeword/openwakeword/resources/models/embedding_model.tflite')
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: './openwakeword/openwakeword/resources/models'

# %%
# Imports

import os
import numpy as np
import torch
import sys
from pathlib import Path
import uuid
import yaml
import datasets
import scipy
from tqdm import tqdm

# %% [markdown]
# # Download Data

# %% [markdown]
# When training new openWakeWord models using the automated procedure, four specific types of data are required:
#
# 1) Synthetic examples of the target word/phrase generated with text-to-speech models
#
# 2) Synthetic examples of adversarial words/phrases generated with text-to-speech models
#
# 3) Room impulse reponses and noise/background audio data to augment the synthetic examples and make them more realistic
#
# 4) Generic "negative" audio data that is very unlikely to contain examples of the target word/phrase in the context where the model should detect it. This data can be the original audio data, or precomputed openWakeWord features ready for model training.
#
# 5) Validation data to use for early-stopping when training the model.
#
# For the purposes of this notebook, all five of these sources will either be generated manually or can be obtained from HuggingFace thanks to their excellent `datasets` library and extremely generous hosting policy. Also note that while only a portion of some datasets are downloaded, for the best possible performance it is recommended to download the entire dataset and keep a local copy for future training runs.

# %%
# Download room impulse responses collected by MIT
# https://mcdermottlab.mit.edu/Reverb/IR_Survey.html

output_dir = "./mit_rirs"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
rir_dataset = datasets.load_dataset("davidscripka/MIT_environmental_impulse_responses", split="train", streaming=True)

# Save clips to 16-bit PCM wav files
for row in tqdm(rir_dataset):
    name = row['audio']['path'].split('/')[-1]
    scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))

# %%
## Download noise and background audio

# Audioset Dataset (https://research.google.com/audioset/dataset/index.html)
# Download one part of the audioset .tar files, extract, and convert to 16khz
# For full-scale training, it's recommended to download the entire dataset from
# https://huggingface.co/datasets/agkphysics/AudioSet, and
# even potentially combine it with other background noise datasets (e.g., FSD50k, Freesound, etc.)

if not os.path.exists("audioset"):
    os.mkdir("audioset")

fname = "bal_train09.tar"
out_dir = f"audioset/{fname}"
link = "https://huggingface.co/datasets/agkphysics/AudioSet/resolve/main/data/" + fname
# !wget -O {out_dir} {link}
# !cd audioset && tar -xvf bal_train09.tar

output_dir = "./audioset_16k"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

# Convert audioset files to 16khz sample rate
audioset_dataset = datasets.Dataset.from_dict({"audio": [str(i) for i in Path("audioset/audio").glob("**/*.flac")]})
audioset_dataset = audioset_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000))
for row in tqdm(audioset_dataset):
    name = row['audio']['path'].split('/')[-1].replace(".flac", ".wav")
    scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))

# Free Music Archive dataset (https://github.com/mdeff/fma)
output_dir = "./fma"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
fma_dataset = datasets.load_dataset("rudraml/fma", name="small", split="train", streaming=True)
fma_dataset = iter(fma_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000)))

n_hours = 1  # use only 1 hour of clips for this example notebook, recommend increasing for full-scale training
for i in tqdm(range(n_hours*3600//30)):  # this works because the FMA dataset is all 30 second clips
    row = next(fma_dataset)
    name = row['audio']['path'].split('/')[-1].replace(".mp3", ".wav")
    scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))
    i += 1
    if i == n_hours*3600//30:
        break

# %%
# Download pre-computed openWakeWord features for training and validation

# training set (~2,000 hours from the ACAV100M Dataset)
# See https://huggingface.co/datasets/davidscripka/openwakeword_features for more information
# !wget https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/openwakeword_features_ACAV100M_2000_hrs_16bit.npy

# validation set for false positive rate estimation (~11 hours)
# !wget https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/validation_set_features.npy

# %% [markdown]
# # Define Training Configuration

# %% [markdown]
# For automated model training openWakeWord uses a specially designed training script and a [YAML](https://yaml.org/) configuration file that defines all of the information required for training a new wake word/phrase detection model.
#
# It is strongly recommended that you review [the example config file](../examples/custom_model.yml), as each value is fully documented there. For the purposes of this notebook, we'll read in the YAML file to modify certain configuration parameters before saving a new YAML file for training our example model. Specifically:
#
# - We'll train a detection model for the phrase "hey sebastian"
# - We'll only generate 5,000 positive and negative examples (to save on time for this example)
# - We'll only generate 1,000 validation positive and negative examples for early stopping (again to save time)
# - The model will only be trained for 10,000 steps (larger datasets will benefit from longer training)
# - We'll reduce the target metrics to account for the small dataset size and limited training.
#
# On the topic of target metrics, there are *not* specific guidelines about what these metrics should be in practice, and you will need to conduct testing in your target deployment environment to establish good thresholds. However, from very limited testing the default values in the config file (accuracy >= 0.7, recall >= 0.5, false-positive rate <= 0.2 per hour) seem to produce models with reasonable performance.

# %%
# Load default YAML config file for training
config = yaml.load(open("openwakeword/examples/custom_model.yml", 'r').read(), yaml.Loader)
config

# %%
# Modify values in the config and save a new version

config["target_phrase"] = ["hey sebastian"]
config["model_name"] = config["target_phrase"][0].replace(" ", "_")
config["n_samples"] = 1000
config["n_samples_val"] = 1000
config["steps"] = 10000
config["target_accuracy"] = 0.6
config["target_recall"] = 0.25

config["background_paths"] = ['./audioset_16k', './fma']  # multiple background datasets are supported
config["false_positive_validation_data_path"] = "validation_set_features.npy"
config["feature_data_files"] = {"ACAV100M_sample": "openwakeword_features_ACAV100M_2000_hrs_16bit.npy"}

with open('my_model.yaml', 'w') as file:
    documents = yaml.dump(config, file)

# %% [markdown]
# # Train the Model

# %% [markdown]
# With the data downloaded and training configuration set, we can now start training the model. We'll do this in parts to better illustrate the sequence, but you can also execute every step at once for a fully automated process.

# %%
# Step 1: Generate synthetic clips
# For the number of clips we are using, this should take ~10 minutes on a free Google Colab instance with a T4 GPU
# If generation fails, you can simply run this command again as it will continue generating until the
# number of files meets the targets specified in the config file

# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --generate_clips

# %%
# Step 2: Augment the generated clips

# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --augment_clips

# %%
# Step 3: Train model

# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --train_model

# %%
# Step 4 (Optional): On Google Colab, sometimes the .tflite model isn't saved correctly
# If so, run this cell to retry

# Manually save to tflite as this doesn't work right in colab
def convert_onnx_to_tflite(onnx_model_path, output_path):
    """Converts an ONNX version of an openwakeword model to the Tensorflow tflite format."""
    # imports
    import onnx
    import logging
    import tempfile
    from onnx_tf.backend import prepare
    import tensorflow as tf

    # Convert to tflite from onnx model
    onnx_model = onnx.load(onnx_model_path)
    tf_rep = prepare(onnx_model, device="CPU")
    with tempfile.TemporaryDirectory() as tmp_dir:
        tf_rep.export_graph(os.path.join(tmp_dir, "tf_model"))
        converter = tf.lite.TFLiteConverter.from_saved_model(os.path.join(tmp_dir, "tf_model"))
        tflite_model = converter.convert()

        logging.info(f"####\nSaving tflite mode to '{output_path}'")
        with open(output_path, 'wb') as f:
            f.write(tflite_model)

    return None

convert_onnx_to_tflite(f"my_custom_model/{config['model_name']}.onnx", f"my_custom_model/{config['model_name']}.tflite")

# %% [markdown]
# After the model finishes training, the auto training script will automatically convert it to ONNX and tflite versions, saving them as `my_custom_model/<model_name>.onnx/tflite` in the present working directory, where `<model_name>` is defined in the YAML training config file. Either version can be used as normal with `openwakeword`. I recommend testing them with the [`detect_from_microphone.py`](https://github.com/dscripka/openWakeWord/blob/main/examples/detect_from_microphone.py) example script to see how the model performs!
